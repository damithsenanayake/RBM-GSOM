# %%
from AEGSOM import GSOM
from sklearn.manifold import TSNE, Isomap, MDS
from sklearn.decomposition import KernelPCA,FactorAnalysis
import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
rng = np.random.RandomState(seed=1234)
dat = rng.random_sample((100, 3))
from AutoEncoder import AutoEncoder


def vis_weights(node, v, h):
    w1 = gsom.learners[node].w1.T
    
    visualizeW1(w1, v, h)
    

def visualizeW1(opt_W1, vis_patch_side, hid_patch_side):

    """ Add the weights as a matrix of images """

    figure, axes = plt.subplots(nrows = hid_patch_side,
                                              ncols = hid_patch_side)
    index = 0

    for axis in axes.flat:

        """ Add row of weights as an image to the plot """

        image = axis.imshow(opt_W1[index, :].reshape(vis_patch_side, vis_patch_side),
                            cmap = plt.cm.gray, interpolation = 'nearest')
        axis.set_frame_on(False)
        axis.set_axis_off()
        index += 1

    """ Show the obtained plot """

    plt.show()

# %%
fi = pd.read_csv('../mnist_train.csv', header=None)
test = pd.read_csv('../mnist_test.csv', header=None)
dat =np.array(fi)[:, 1:]/255.0
labels = np.array(fi)[:, 0]
# reductor = AutoEncoder(hid_size=100)
# X = reductor.reduce(dat)

gsom = GSOM(dims=784, hid = 49, sf = 0.8, fd = 0.9, max_nodes = 2000, min_nodes = 10, radius=25, scale = 1, nei=True, X=dat, gaussian=True)


for i in range(60):
    print '\nbatch '+ str(i+1)
    prune = False
    if i %4 ==1:
        prune = True
    gsom.train_batch(dat[i*500:(i+1)*500], lr = np.exp(-i/ 40),  iterations=1, prune = False)#lr=0.01*np.exp(-i/200), iterations=100)
# Out:
# batch 1
#  epoch 1 / 1 :  0% : nodes - 4
# AEGSOM.py:19: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X != None:
#  epoch 1 / 1 :  63% : nodes - 12
# AutoEncoder.py:31: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if w1!= None:
#  epoch 1 / 1 :  100% : nodes - 59
# batch 2
#  epoch 1 / 1 :  100% : nodes - 103
# batch 3
#  epoch 1 / 1 :  100% : nodes - 187
# batch 4
#  epoch 1 / 1 :  100% : nodes - 260
# batch 5
#  epoch 1 / 1 :  100% : nodes - 314
# batch 6
#  epoch 1 / 1 :  100% : nodes - 386
# batch 7
#  epoch 1 / 1 :  100% : nodes - 443
# batch 8
#  epoch 1 / 1 :  100% : nodes - 509
# batch 9
#  epoch 1 / 1 :  100% : nodes - 571
# batch 10
#  epoch 1 / 1 :  100% : nodes - 636
# batch 11
#  epoch 1 / 1 :  100% : nodes - 688
# batch 12
#  epoch 1 / 1 :  100% : nodes - 754
# batch 13
#  epoch 1 / 1 :  100% : nodes - 811
# batch 14
#  epoch 1 / 1 :  100% : nodes - 860
# batch 15
#  epoch 1 / 1 :  100% : nodes - 918
# batch 16
#  epoch 1 / 1 :  100% : nodes - 986
# batch 17
#  epoch 1 / 1 :  100% : nodes - 1035
# batch 18
#  epoch 1 / 1 :  100% : nodes - 1085
# batch 19
#  epoch 1 / 1 :  100% : nodes - 1145
# batch 20
#  epoch 1 / 1 :  100% : nodes - 1213
# batch 21
#  epoch 1 / 1 :  100% : nodes - 1272
# batch 22
#  epoch 1 / 1 :  100% : nodes - 1321
# batch 23
#  epoch 1 / 1 :  100% : nodes - 1387
# batch 24
#  epoch 1 / 1 :  100% : nodes - 1447
# batch 25
#  epoch 1 / 1 :  100% : nodes - 1499
# batch 26
#  epoch 1 / 1 :  100% : nodes - 1548
# batch 27
#  epoch 1 / 1 :  100% : nodes - 1589
# batch 28
#  epoch 1 / 1 :  100% : nodes - 1628
# batch 29
#  epoch 1 / 1 :  100% : nodes - 1672
# batch 30
#  epoch 1 / 1 :  100% : nodes - 1717
# batch 31
#  epoch 1 / 1 :  100% : nodes - 1756
# batch 32
#  epoch 1 / 1 :  100% : nodes - 1786
# batch 33
#  epoch 1 / 1 :  100% : nodes - 1807
# batch 34
#  epoch 1 / 1 :  100% : nodes - 1841
# batch 35
#  epoch 1 / 1 :  100% : nodes - 1872
# batch 36
#  epoch 1 / 1 :  100% : nodes - 1913
# batch 37
#  epoch 1 / 1 :  100% : nodes - 1933
# batch 38
#  epoch 1 / 1 :  100% : nodes - 1957
# batch 39
#  epoch 1 / 1 :  100% : nodes - 1984
# batch 40
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 41
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 42
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 43
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 44
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 45
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 46
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 47
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 48
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 49
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 50
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 51
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 52
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 53
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 54
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 55
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 56
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 57
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 58
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 59
#  epoch 1 / 1 :  100% : nodes - 2000
# batch 60
#  epoch 1 / 1 :  100% : nodes - 2000

# %%
grid, hits = gsom.predict((dat[:1000]))
x, y = grid.T
colors = dat
nodes = np.unique(np.array(hits))

batches = []

for n in nodes:
    ninds = np.where(np.array(hits)==n)[0]
    batches.append(dat[ninds])

plt.scatter(x, y, s=1, c = 'white')

for i, j, t in zip(x, y, labels):
    plt.text(i, j, t, color = plt.cm.Set1(t/10.0), fontsize = 12)
plt.show()

plt.scatter(x, y, s=1)


map = gsom.grid.values()
hits = gsom.hits.values()

x, y = np.array(map).T

for i, j, t in zip(x,y,hits):
    plt.text(i, j, t, color = 'green', fontsize = 12)

plt.show()

# %%
w1 = gsom.learners[str([-3,0])].w1

#visualizeW1(w1.T, 28, 1)

plt.imshow(w1.T[0].reshape(28, 28))
plt.gray()
plt.show()
